# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Pandas_PreClass_2 (Series & DataFrames)</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # <font color='green'> <b>Importing Libraries </b><font color='black'>

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(42)

seri = pd.Series(np.random.randint(0, 50, 8))
seri
# Out:
# 0    38
# 1    28
# 2    14
# 3    42
# 4     7
# 5    20
# 6    38
# 7    18
# dtype: int32

# %%
seri.shape
# Out:
# (8,)

# %%
seri.ndim
# Out:
# 1

# %%
seri.head() # ilk 5 tanesini getirir. default 5'tir
# Out:
# 0    38
# 1    28
# 2    14
# 3    42
# 4     7
# dtype: int32

# %%
seri.head(3) #ilk 3 tanesini getirir
# Out:
# 0    38
# 1    28
# 2    14
# dtype: int32

# %%
seri.tail # son 5 tanesini getirir. default 5'tir
# Out:
# <bound method NDFrame.tail of 0    38
# 1    28
# 2    14
# 3    42
# 4     7
# 5    20
# 6    38
# 7    18
# dtype: int32>

# %%
seri.tail(3) #son 3 tanesini getirir
# Out:
# 5    20
# 6    38
# 7    18
# dtype: int32

# %%
seri.sample() # rastgele bir satır döndürür. her seferinde değişir
# Out:
# 0    38
# dtype: int32

# %%
seri.sample(3) # rastgele üçr satır döndürür. her seferinde değişir
# Out:
# 7    18
# 2    14
# 0    38
# dtype: int32

# %%
seri.sort_values() #values sıralar
# Out:
# 4     7
# 2    14
# 7    18
# 5    20
# 1    28
# 0    38
# 6    38
# 3    42
# dtype: int32

# %%
qq = seri.sort_values(ascending=False) #ascending default True'dur. False olursa büyükten küçüğe sıralar
qq
# Out:
# 3    42
# 0    38
# 6    38
# 1    28
# 5    20
# 7    18
# 2    14
# 4     7
# dtype: int32

# %%
qq.sort_index()
# Out:
# 0    38
# 1    28
# 2    14
# 3    42
# 4     7
# 5    20
# 6    38
# 7    18
# dtype: int32

# %%
qq.values
# Out:
# array([42, 38, 38, 28, 20, 18, 14,  7])

# %%
qq.isnull()
# Out:
# 3    False
# 0    False
# 6    False
# 1    False
# 5    False
# 7    False
# 2    False
# 4    False
# dtype: bool

# %%
xx = pd.Series([1,2,3,4,5,6,7,8]) #series türü int 64. bir alt örneği incele

# %%
xx = pd.Series([1,2,3,np.nan,4,5,6,7,8]) #içinde 1 tane nan olduğu için series türü değişir.int64'ten float 64'e değişir
xx
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# 6    6.0
# 7    7.0
# 8    8.0
# dtype: float64

# %%
xx.fillna(222) #nan değeri 222 ile değşitirir
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3    222.0
# 4      4.0
# 5      5.0
# 6      6.0
# 7      7.0
# 8      8.0
# dtype: float64

# %%
dd = pd.Series([1,2,3,4,5,np.nan,6,7,8,np.nan])
dd
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    NaN
# 6    6.0
# 7    7.0
# 8    8.0
# 9    NaN
# dtype: float64

# %%
dd.dropna() #nan değerleri kaldırır. kalıcı olması için değşikene atanması gerekir
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 6    6.0
# 7    7.0
# 8    8.0
# dtype: float64

# %%
 #3.0 değerinin olduğu index True olur

# %%
qq.describe
# Out:
# <bound method NDFrame.describe of 3    42
# 0    38
# 6    38
# 1    28
# 5    20
# 7    18
# 2    14
# 4     7
# dtype: int32>

# %%
seri.sort_index() #index değerlerini sıralar
# Out:
# 0    38
# 1    28
# 2    14
# 3    42
# 4     7
# 5    20
# 6    38
# 7    18
# dtype: int32

# %%
seri.sort_index(ascending=False) #index değerlerini ascending sıralar
# Out:
# 7    18
# 6    38
# 5    20
# 4     7
# 3    42
# 2    14
# 1    28
# 0    38
# dtype: int32

# %% [markdown]
# ## <font color='blue'> <b>Basic Attributes & Methods of Series</b><font color='black'>

# %% [markdown]
# **SOME COMMON ATTRIBUTES** [Official Pandas API Document](https://pandas.pydata.org/docs/reference/api/pandas.Series.html)<br>
#
# **Series.values:** Serinin değerlerinin Numpy dizisi (array) olarak döndürülmesini sağlar.
#
# **Series.index:**  Serinin indekslerinin döndürülmesini sağlar.
#
# **Series.dtype:**  Serinin veri tipini döndürür.
#
# **Series.size:**   Serinin eleman sayısını döndürür.
#
# **Series.shape:**  Serinin boyutunu döndürür.
#
# **Series.ndim:**   Serinin boyut sayısını döndürür.
#
# **Series.head():** Serinin ilk n adet elemanını döndürür.
#
# **Series.tail():** Serinin son n adet elemanını döndürür.
#
# **Series.sample():** Serinin random n adet elemanını döndürür.
#
# **Series.describe():** Serinin istatistiksel özetini döndürür.
#
# **Series.sort_index:** Seriyi indexlerine göre sıralar.
#
# **Series.sort_values():** Seriyi değerlerine göre sıralar.
#
# **Series.isnull():**      Serinin her bir elemanının null (None) olup olmadığını kontrol eder.
#
# **Series.fillna():**      Null değerleri belirli bir değerle doldurur.
#
# **Series.dropna():**      Null değerleri seriden çıkarır.
#
# **Series.isin:**        Serideki öğelerin değerlerde yer alıp almadığını kontrol eder.

# %% [markdown]
# # <font color='green'> <b>DataFrames </b><font color='black'>

# %% [markdown]
# ## <font color='blue'> <b>Creating a DataFrame</b><font color='black'>
#
# DataFrame, iki boyutlu bir veri koleksiyonudur.
#
# Verilerin tablo şeklinde (tabular) saklandığı bir veri yapısıdır.
#
# Veri kümeleri satırlar ve sütunlar halinde düzenlenir; veri çerçevesinde birden çok veri kümesi depolayabiliriz.
#
# DataFrame'i, aynı dizini paylaşmak için bir araya getirilmiş bir dizi Series nesnesi olarak düşünebiliriz.
#
# Veri çerçevesine sütun/satır seçimi ve sütun/satır ekleme gibi çeşitli aritmetik işlemleri gerçekleştirebiliriz.
#
# DataFrame'leri harici depolamadan içe aktarabiliriz; SQL Veritabanı, CSV dosyası ve bir Excel dosyası.
#
# [SOURCE01](https://www.tutorialspoint.com/python_pandas/python_pandas_dataframe.htm),
# [SOURCE02](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html),
# [SOURCE03](https://morioh.com/p/2528ac775b1b),
# [SOURCE04](https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python),
# [SOURCE05](https://www.guru99.com/python-pandas-tutorial.html),
# [SOURCE06](https://realpython.com/pandas-dataframe/) &
# [SOURCE07](https://towardsdatascience.com/a-simple-guide-to-pandas-dataframes-b125f64e1453)<br>
# [VIDEO SOURCE01](https://www.youtube.com/watch?v=zmdjNSmRXF4),
# [VIDEO SOURCE02](https://www.youtube.com/watch?v=F6kmIpWWEdU) &
# [VIDEO SOURCE03](https://towardsdatascience.com/pandas-dataframe-basics-3c16eb35c4f3)<br>

# %% [markdown]
# ### <font color='blue'> <b>Creating a DataFrame Using the Lists of Data & Columns</b><font color='black'>

# %%
list_1 = [[1,2,3],[4,5,6]]

column_name = ["A", "B", "C"]

df = pd.DataFrame(data = list_1, columns= column_name)
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
list_1 = [[1,2,3]]

column_name = ["A", "B", "C"]

df = pd.DataFrame(data = list_1, columns= column_name)
df
# Out:
#    A  B  C
# 0  1  2  3

# %%
df = pd.DataFrame(data =np.array(list(range(1,100))).reshape(-1,3), columns=["A","B","C"], index=list(range(1,34)))
df
# Out:
#      A   B   C
# 1    1   2   3
# 2    4   5   6
# 3    7   8   9
# 4   10  11  12
# 5   13  14  15
# 6   16  17  18
# 7   19  20  21
# 8   22  23  24
# 9   25  26  27
# 10  28  29  30
# 11  31  32  33
# 12  34  35  36
# 13  37  38  39
# 14  40  41  42
# 15  43  44  45
# 16  46  47  48
# 17  49  50  51
# 18  52  53  54
# 19  55  56  57
# 20  58  59  60
# 21  61  62  63
# 22  64  65  66
# 23  67  68  69
# 24  70  71  72
# 25  73  74  75
# 26  76  77  78
# 27  79  80  81
# 28  82  83  84
# 29  85  86  87
# 30  88  89  90
# 31  91  92  93
# 32  94  95  96
# 33  97  98  99

# %%
list_1 = [[1,2,3],[4,5,6]]

column_name = ["A", "B", "C"]

df = pd.DataFrame(data = list_1, columns= column_name)
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %% [markdown]
# ### <font color='blue'> <b>Creating a DataFrame Using a Numpy Arrays</b><font color='black'>

# %%
arr1 = np.arange(1,27,3).reshape(3,3)
arr1
# Out:
# array([[ 1,  4,  7],
#        [10, 13, 16],
#        [19, 22, 25]])

# %%
arr1.ndim
# Out:
# 2

# %%
df = pd.DataFrame(data = arr1) #data= yazmasak da olur. aşağıdaki örnek
df
# Out:
#     0   1   2
# 0   1   4   7
# 1  10  13  16
# 2  19  22  25

# %%
df = pd.DataFrame(data = arr1, columns = ["A1","A2","A3"])
df
# Out:
#    A1  A2  A3
# 0   1   4   7
# 1  10  13  16
# 2  19  22  25

# %%
df = pd.DataFrame(arr1, ["A1","A2","A3"])
df #2. positional indextir
# Out:
#      0   1   2
# A1   1   4   7
# A2  10  13  16
# A3  19  22  25

# %%
df = pd.DataFrame(arr1, columns=["A1","A2","A3"], index = ["B1","B2", "B3"])
df
# Out:
#     A1  A2  A3
# B1   1   4   7
# B2  10  13  16
# B3  19  22  25

# %% [markdown]
# ### <font color='blue'> <b>Creating a DataFrame Using a Dictionary</b><font color='black'>

# %%
data = {'Name':['Ayşe', 'Ahmet', 'Mehmet'],'Age':[20,30,40]}
data
# Out:
# {'Name': ['Ayşe', 'Ahmet', 'Mehmet'], 'Age': [20, 30, 40]}

# %%
pd.Series(data)
# Out:
# Name    [Ayşe, Ahmet, Mehmet]
# Age              [20, 30, 40]
# dtype: object

# %%
pd.DataFrame(data) #data=data yazsak da olur, yazmasak da
# Out:
#      Name  Age
# 0    Ayşe   20
# 1   Ahmet   30
# 2  Mehmet   40

# %%
pd.DataFrame(data=data) #parametre = argument
# Out:
#      Name  Age
# 0    Ayşe   20
# 1   Ahmet   30
# 2  Mehmet   40

# %%
pd.DataFrame(data,columns = ["Name","Age","Job"])
# Out:
#      Name  Age  Job
# 0    Ayşe   20  NaN
# 1   Ahmet   30  NaN
# 2  Mehmet   40  NaN

# %%
aa = pd.DataFrame(data,columns = ["aa","bb","cc"])
aa
# Out:
# Empty DataFrame
# Columns: [aa, bb, cc]
# Index: []

# %%
aa.shape
# Out:
# (0, 3)

# %%
df = pd.DataFrame(data,columns = ["Name","bb","cc"])
df
# Out:
#      Name   bb   cc
# 0    Ayşe  NaN  NaN
# 1   Ahmet  NaN  NaN
# 2  Mehmet  NaN  NaN

# %%
df.shape
# Out:
# (3, 3)

# %% [markdown]
# ## <font color='blue'> <b>Basic Attributes & Methods of DataFrames</b><font color='black'>

# %%
dict_1 = {'Name':['Ayşe', 'Ahmet', 'Mehmet'],'Age':[20,30,40]}
dict_1
# Out:
# {'Name': ['Ayşe', 'Ahmet', 'Mehmet'], 'Age': [20, 30, 40]}

# %%
df = pd.DataFrame(data = dict_1)
df
# Out:
#      Name  Age
# 0    Ayşe   20
# 1   Ahmet   30
# 2  Mehmet   40

# %%
df.head() #5 tane olmadığı için 3 tanesini getirdi
# Out:
#      Name  Age
# 0    Ayşe   20
# 1   Ahmet   30
# 2  Mehmet   40

# %%
df.head(2)
# Out:
#     Name  Age
# 0   Ayşe   20
# 1  Ahmet   30

# %%
df.tail(2)
# Out:
#      Name  Age
# 1   Ahmet   30
# 2  Mehmet   40

# %%
df.sample() #her çalışmada random bir değer (sample) getirir. popülasyondan örneklem getirir
# Out:
#    Name  Age
# 0  Ayşe   20

# %%
df.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %%
df.columns[0]
# Out:
# 'Name'

# %%
df.columns[1]
# Out:
# 'Age'

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.Age
# Out:
# 0    20
# 1    30
# 2    40
# Name: Age, dtype: int64

# %%
df.Age.mean() #mean işlemi nümeric sütunlarla yapılır. sadece df.mean()deseydik hata verirdi
# Out:
# 30.0

# %% [markdown]
# ## <font color='blue'> <b>Indexing, Slicing & Selection</b><font color='black'>

# %% [markdown]
# [Source01](https://pandas.pydata.org/docs/user_guide/indexing.html),
# [Source02](https://www.geeksforgeeks.org/slicing-indexing-manipulating-and-cleaning-pandas-dataframe/),
# [Source03](https://www.tutorialspoint.com/python_pandas/python_pandas_indexing_and_selecting_data.htm),
# [Source04](https://www.dataquest.io/blog/tutorial-indexing-dataframes-in-pandas/)

# %%
data={"isim":["Ali", "Ayşe", "Fatma", "Veli"], "boy cm":[170,160,170,180], "kilo-kg":[70, 55, 60, 80]}
data
# Out:
# {'isim': ['Ali', 'Ayşe', 'Fatma', 'Veli'],
#  'boy cm': [170, 160, 170, 180],
#  'kilo-kg': [70, 55, 60, 80]}

# %%
df = pd.DataFrame (data=data, index = ["A","B","C","D"])
df
# Out:
#     isim  boy cm  kilo-kg
# A    Ali     170       70
# B   Ayşe     160       55
# C  Fatma     170       60
# D   Veli     180       80

# %%
df.shape
# Out:
# (4, 3)

# %%
df.isim # alttaki gibi de aynı sonuç çıkarır
# Out:
# A      Ali
# B     Ayşe
# C    Fatma
# D     Veli
# Name: isim, dtype: object

# %%
df["isim"]
# Out:
# A      Ali
# B     Ayşe
# C    Fatma
# D     Veli
# Name: isim, dtype: object

# %%
df.columns
# Out:
# Index(['isim', 'boy cm', 'kilo-kg'], dtype='object')

# %%
df["boy cm"] #alttireli olsa iyi olur
# Out:
# A    170
# B    160
# C    170
# D    180
# Name: boy cm, dtype: int64

# %%
df["kilo-kg"]  #type = series
# Out:
# A    70
# B    55
# C    60
# D    80
# Name: kilo-kg, dtype: int64

# %%
a = df["kilo-kg"] #pandas series (tek köşeli parantez)
type(a)
# Out:
# pandas.core.series.Series

# %%
df[["kilo-kg"]] #type = dataframe (çift köşeli parantez)
# Out:
#    kilo-kg
# A       70
# B       55
# C       60
# D       80

# %%
b = df[["kilo-kg"]]
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
b.shape
# Out:
# (4, 1)

# %%
df = df[["kilo-kg"]]
df
# Out:
#    kilo-kg
# A       70
# B       55
# C       60
# D       80

# %%
data={"isim":["Ali", "Ayşe", "Fatma", "Veli"], "boy cm":[170,160,170,180], "kilo-kg":[70, 55, 60, 80]}

# %%
df = pd.DataFrame (data=data, index = ["A","B","C","D"])
df
# Out:
#     isim  boy cm  kilo-kg
# A    Ali     170       70
# B   Ayşe     160       55
# C  Fatma     170       60
# D   Veli     180       80

# %%
df["A":"C"]
# Out:
#     isim  boy cm  kilo-kg
# A    Ali     170       70
# B   Ayşe     160       55
# C  Fatma     170       60

# %%
df[0:1]
# Out:
#   isim  boy cm  kilo-kg
# A  Ali     170       70

# %% [markdown]
# ## <font color='blue'> <b>Creating a New Column</b><font color='black'>

# %%
df
# Out:
#     isim  boy cm  kilo-kg
# A    Ali     170       70
# B   Ayşe     160       55
# C  Fatma     170       60
# D   Veli     180       80

# %%
df["BMI"] = round(df["kilo-kg"] / ((df["boy cm"] / 100) ** 2),2)
df
# Out:
#     isim  boy cm  kilo-kg    BMI
# A    Ali     170       70  24.22
# B   Ayşe     160       55  21.48
# C  Fatma     170       60  20.76
# D   Veli     180       80  24.69

# %%
df["new"] = np.arange(4)

# %%
df
# Out:
#     isim  boy cm  kilo-kg    BMI  new
# A    Ali     170       70  24.22    0
# B   Ayşe     160       55  21.48    1
# C  Fatma     170       60  20.76    2
# D   Veli     180       80  24.69    3

# %%
df = pd.read_csv("adult_eda.csv")
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors           13.0
# 1       50  Self-emp-not-inc   83311   Bachelors           13.0
# 2       38           Private  215646     HS-grad            9.0
# 3       53           Private  234721        11th            7.0
# 4       28           Private  338409   Bachelors           13.0
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm           12.0
# 32557   40           Private  154374     HS-grad            9.0
# 32558   58           Private  151910     HS-grad            9.0
# 32559   22           Private  201490     HS-grad            9.0
# 32560   52      Self-emp-inc  287927     HS-grad            9.0
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32556   27       Private  257302  Assoc-acdm           12.0
# 32557   40       Private  154374     HS-grad            9.0
# 32558   58       Private  151910     HS-grad            9.0
# 32559   22       Private  201490     HS-grad            9.0
# 32560   52  Self-emp-inc  287927     HS-grad            9.0
#
#            marital-status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical          NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K

# %%
df.dtypes #pd.DataFrame attribute (dtype olsa series metodu, hata verir. dtypes olacak.)
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# education-num     float64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# sex                object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# salary             object
# dtype: object

# %%
df.size
# Out:
# 488415

# %%
df[32559:32560]
# Out:
#        age workclass  fnlwgt education  education-num marital-status  \
# 32559   22   Private  201490   HS-grad            9.0  Never-married
#
#          occupation relationship   race   sex  capital-gain  capital-loss  \
# 32559  Adm-clerical          NaN  White  Male             0             0
#
#        hours-per-week native-country salary
# 32559              20  United-States  <=50K

# %%
df[32559:32560]["relationship"]
# Out:
# 32559    NaN
# Name: relationship, dtype: object

# %%
type(df[32559:32560]["relationship"])
# Out:
# pandas.core.series.Series

# %%
list(df[32559:32560]["relationship"])[0]
# Out:
# nan

# %%
type(list(df[32559:32560]["relationship"])[0])
# Out:
# float

# %%
type(list(df[32557:32558]["relationship"])[0])
# Out:
# str

# %%
df.ndim
# Out:
# 2

# %%
df.sample()
# Out:
#       age workclass  fnlwgt     education  education-num marital-status  \
# 4413   20         ?  193416  Some-college           10.0  Never-married
#
#      occupation relationship   race     sex  capital-gain  capital-loss  \
# 4413          ?          NaN  White  Female             0             0
#
#       hours-per-week native-country salary
# 4413              40  United-States  <=50K

# %%
df.sample(20) #20 tane rastgele getirir
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 23524   22           Private   81145       HS-grad            9.0
# 25683   27           Private  106039     Bachelors           13.0
# 28153   67         Local-gov  190661     Doctorate           16.0
# 30069   38         Local-gov  287658       Masters           14.0
# 21808   22           Private  208946  Some-college           10.0
# 6100    54           Private  118108       HS-grad            9.0
# 24065   36           Private   68273     Bachelors            NaN
# 9203    21           Private  197182    Assoc-acdm           12.0
# 26003   33           Private  341187     Bachelors           13.0
# 28903   50           Private  271262       HS-grad            9.0
# 13813   31           Private   43819     Bachelors           13.0
# 9680    29           Private  115677     Bachelors           13.0
# 15409   62           Private  210142     Assoc-voc           11.0
# 24472   40           Private  137142       HS-grad            9.0
# 6111    39           Private   91711       Masters           14.0
# 15242   37           Private  233571     Assoc-voc           11.0
# 15025   37           Private  210438          11th            7.0
# 13757   48           Private  255439  Some-college            NaN
# 29451   32  Self-emp-not-inc   62272       HS-grad            9.0
# 5230    20         State-gov  161978  Some-college           10.0
#
#            marital-status         occupation   relationship   race     sex  \
# 23524       Never-married      Other-service  Not-in-family  White  Female
# 25683            Divorced     Prof-specialty            NaN  White  Female
# 28153       Never-married     Prof-specialty  Not-in-family  White  Female
# 30069            Divorced     Prof-specialty  Not-in-family  Black    Male
# 21808       Never-married  Machine-op-inspct  Not-in-family  White    Male
# 6100   Married-civ-spouse       Craft-repair        Husband  Black    Male
# 24065  Married-civ-spouse              Sales        Husband  White    Male
# 9203        Never-married     Prof-specialty  Not-in-family  White  Female
# 26003  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 28903  Married-civ-spouse   Transport-moving        Husband  White    Male
# 13813  Married-civ-spouse     Prof-specialty           Wife  White  Female
# 9680        Never-married       Tech-support  Not-in-family  White    Male
# 15409  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 24472  Married-civ-spouse              Sales        Husband  White    Male
# 6111   Married-civ-spouse    Exec-managerial        Husband  White    Male
# 15242  Married-civ-spouse       Tech-support           Wife  White  Female
# 15025       Never-married  Handlers-cleaners  Not-in-family  Black    Male
# 13757       Never-married  Handlers-cleaners  Not-in-family  White    Male
# 29451            Divorced    Exec-managerial      Unmarried  White  Female
# 5230   Married-civ-spouse      Other-service        Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 23524             0             0              25  United-States  <=50K
# 25683             0             0              50  United-States  <=50K
# 28153          7896             0              50  United-States   >50K
# 30069             0             0              40        Jamaica  <=50K
# 21808             0             0              40  United-States  <=50K
# 6100              0             0              40  United-States  <=50K
# 24065             0             0              40  United-States   >50K
# 9203              0             0              40  United-States  <=50K
# 26003             0             0              50  United-States   >50K
# 28903             0             0              40  United-States   >50K
# 13813          7688             0              43  United-States   >50K
# 9680              0             0              40  United-States  <=50K
# 15409             0             0              50  United-States   >50K
# 24472             0             0              40  United-States   >50K
# 6111              0             0              40  United-States   >50K
# 15242             0             0              37  United-States   >50K
# 15025             0             0              40  United-States  <=50K
# 13757             0             0              40  United-States  <=50K
# 29451             0             0              40  United-States  <=50K
# 5230              0             0              20  United-States  <=50K

# %%
df.isnull() #False ise boş veri olmadığı anlamına gelir
# Out:
#          age  workclass  fnlwgt  education  education-num  marital-status  \
# 0      False      False   False      False          False           False
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 32556  False      False   False      False          False           False
# 32557  False      False   False      False          False           False
# 32558  False      False   False      False          False           False
# 32559  False      False   False      False          False           False
# 32560  False      False   False      False          False           False
#
#        occupation  relationship   race    sex  capital-gain  capital-loss  \
# 0           False         False  False  False         False         False
# 1           False         False  False  False         False         False
# 2           False         False  False  False         False         False
# 3           False         False  False  False         False         False
# 4           False         False  False  False         False         False
# ...           ...           ...    ...    ...           ...           ...
# 32556       False         False  False  False         False         False
# 32557       False         False  False  False         False         False
# 32558       False         False  False  False         False         False
# 32559       False          True  False  False         False         False
# 32560       False         False  False  False         False         False
#
#        hours-per-week  native-country  salary
# 0               False           False   False
# 1               False           False   False
# 2               False           False   False
# 3               False           False   False
# 4               False           False   False
# ...               ...             ...     ...
# 32556           False           False   False
# 32557           False           False   False
# 32558           False           False   False
# 32559           False           False   False
# 32560           False           False   False
#
# [32561 rows x 15 columns]

# %%
df.isnull().sum() #education 802, relationship 5068 boş değer var
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
data = {"İsim": ["Ali", "Ayşe", "Fatma", "Veli"], "boy cm": [170,160,170,180], "kilo-kg": [70, 60, 60, 80]}
df = pd.DataFrame(data, index= ["A", "B", "C", "D"])
df["BMI"] = df["kilo-kg"] / (df["boy cm"] /100) ** 2
df["new"] = np.arange(4)

# %%
df
# Out:
#     İsim  boy cm  kilo-kg        BMI  new
# A    Ali     170       70  24.221453    0
# B   Ayşe     160       60  23.437500    1
# C  Fatma     170       60  20.761246    2
# D   Veli     180       80  24.691358    3

# %% [markdown]
# ## <font color='blue'> <b>Removing Columns & Rows</b><font color='black'>

# %% [markdown]
# drop() yöntemi, bir Pandas DataFrame'den belirtilen satır veya sütunu kaldırmak için kullanılır.
#
# Eğer sütun kaldırılacaksa, axis='columns' parametresi kullanılır ve belirtilen sütun kaldırılır.
#
# Benzer şekilde, eğer bir satır kaldırılacaksa, axis='index' parametresi kullanılır ve belirtilen satır kaldırılır.
#
# Bu yöntem, DataFrame'den istenmeyen verileri kaldırmak ve veri manipülasyonu yapmak için sıkça kullanılır.

# %%
df.drop("new", axis =1, inplace=True) # axis ="columns" olmazsa ilk önce axis'te arar. bulamayınca hata verir. axis varsayılan değer 0.dır.1 olursa sütun siler. inplace varsayılan değeri False tur. True olursa kalıcı değişiklik sağlar

# %%
df
# Out:
#     İsim  boy cm  kilo-kg        BMI
# A    Ali     170       70  24.221453
# B   Ayşe     160       60  23.437500
# C  Fatma     170       60  20.761246
# D   Veli     180       80  24.691358

# %%
df.drop("C") #inplace olmadığı için kalıcı değil. axis belirtilmediği için satır arar. c satırını siler
# Out:
#    İsim  boy cm  kilo-kg        BMI
# A   Ali     170       70  24.221453
# B  Ayşe     160       60  23.437500
# D  Veli     180       80  24.691358

# %%
df.drop(["C","B"]) #1'den fazla satır silmek istersek liste olarak vermemiz gerekir.
# Out:
#    İsim  boy cm  kilo-kg        BMI
# A   Ali     170       70  24.221453
# D  Veli     180       80  24.691358

# %%
df.drop(["C","B"], inplace=True) #b ve c satırlarını kalıcı siler

# %%
df
# Out:
#    İsim  boy cm  kilo-kg        BMI
# A   Ali     170       70  24.221453
# D  Veli     180       80  24.691358

# %%
df.drop(["boy cm","BMI"], axis =1)
# Out:
#    İsim  kilo-kg
# A   Ali       70
# D  Veli       80

# %% [markdown]
# ## <font color='blue'> <b>Selecting Rows and Columns using .loc[ ] and iloc[ ]</b><font color='black'>

# %% [markdown]
# loc: label-based
#
# iloc: integer position-based
#
# loc, "location"ın kısaltmasıdır ve satır ve sütun adlarına göre veriye erişmeyi sağlar.
#
# loc, satır ve sütun etiketleri kullanarak belirli bir konumda bulunan veriye erişmek için kullanılır.
#
# iloc, "integer location"ın kısaltmasıdır ve satır ve sütun numaralarına göre veriye erişmeyi sağlar.
#
# iloc, satır ve sütun numaralarını kullanarak belirli bir konumda bulunan veriye erişmek için kullanılır.
#
# 1- Etiket veya dizin bağımsızlığı:Geleneksel indexleme yöntemleri, indekslerdeki değişikliklerden etkilenirken, "loc" ve "iloc" yöntemleri, konumlarına göre seçim yaparlar. Bu nedenle, veri setindeki indekslerdeki değişiklikler "loc" ve "iloc" yöntemleriyle yapılan seçimlerde bir sorun yaratmaz.
#
# 2-Hızlı performans: "iloc" fonksiyonu, sadece satır ve sütun dizinleri kullanarak veri seçimi yapar, bu nedenle loc fonksiyonuna göre daha hızlı çalışır. Bu özellik, büyük veri kümelerinde veya performans açısından kritik uygulamalarda faydalıdır.
#
# 3-Esneklik: Geleneksel indexleme yöntemleri, sadece sıfırdan başlayan, ardışık tam sayılar kullanarak indexlemeye izin verir. "loc" ve "iloc" yöntemleri ise etiket veya dizin değerlerine dayanır ve daha esnek bir seçim yapma imkanı sağlar. "loc" ve "iloc" fonksiyonları, veri çerçevesindeki satır ve sütunların bir arada kullanımına izin verir. Örneğin, belirli bir sütunda belirli bir satırdaki veriyi seçmek için hem satır hem de sütun etiketlerini veya dizinlerini kullanabilirsiniz. Bu esneklik, veri işleme işlemlerinde kullanışlıdır.
#
# 4-Daha okunaklı kod: "loc" ve "iloc" fonksiyonları, kodun daha okunaklı hale gelmesine yardımcı olur.

# %%
np.random.seed(45)

data = np.random.randint(1,100,20).reshape(5,4)

df = pd.DataFrame(data, columns =["col1","col2","col3","col4"], index =range(101,106))

df
# Out:
#      col1  col2  col3  col4
# 101    76    31     4    33
# 102    96    62    86    36
# 103    69    16    66    15
# 104    54    58    73    88
# 105    47     9    54    13

# %%
df.loc[103]
# Out:
# col1    69
# col2    16
# col3    66
# col4    15
# Name: 103, dtype: int32

# %%
df.loc[102:104] #102:104 label'dır. biz böyle isimlendirdik
# Out:
#      col1  col2  col3  col4
# 102    96    62    86    36
# 103    69    16    66    15
# 104    54    58    73    88

# %%
df.iloc[1:4] #iloc index numarasıdır.4. index 4 >> 104 'e denk gelir.
# Out:
#      col1  col2  col3  col4
# 102    96    62    86    36
# 103    69    16    66    15
# 104    54    58    73    88

# %%
df
# Out:
#      col1  col2  col3  col4
# 101    76    31     4    33
# 102    96    62    86    36
# 103    69    16    66    15
# 104    54    58    73    88
# 105    47     9    54    13

# %%
df.index
# Out:
# RangeIndex(start=101, stop=106, step=1)

# %%
df.index = "a b c d e".split()

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df.loc["b":"d"]
# Out:
#    col1  col2  col3  col4
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88

# %%
df.iloc[1:4]
# Out:
#    col1  col2  col3  col4
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88

# %%
df.iloc[::2]
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# c    69    16    66    15
# e    47     9    54    13

# %%
df.loc["a":"e":2]
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# c    69    16    66    15
# e    47     9    54    13

# %%
df.loc["a":"c","col3"] # solda satırlar, sağda sütunlar
# Out:
# a     4
# b    86
# c    66
# Name: col3, dtype: int32

# %%
df.loc["a":"c",["col3"]] #dataframe olarak gelir. çift parantez
# Out:
#    col3
# a     4
# b    86
# c    66

# %%
df.iloc[:3,[2]] #iloc verisyonu
# Out:
#    col3
# a     4
# b    86
# c    66

# %%
df.iloc[3:5,1:3]
# Out:
#    col2  col3
# d    58    73
# e     9    54

# %%
df.loc[["d","e"],["col2","col3"]]
# Out:
#    col2  col3
# d    58    73
# e     9    54

# %%
df.loc[["d","e"],"col2":"col3"]
# Out:
#    col2  col3
# d    58    73
# e     9    54

# %%
df.loc["d":"e"]
# Out:
#    col1  col2  col3  col4
# d    54    58    73    88
# e    47     9    54    13

# %%
df.loc["d":"e"]["col2"]
# Out:
# d    58
# e     9
# Name: col2, dtype: int32

# %%
df.loc["d":"e"][["col2"]] #çift köşeli parantez dataframe yapar
# Out:
#    col2
# d    58
# e     9

# %%
df.loc["d":"e"][["col2","col3"]]
# Out:
#    col2  col3
# d    58    73
# e     9    54

# %%
df["col3"]
# Out:
# a     4
# b    86
# c    66
# d    73
# e    54
# Name: col3, dtype: int32

# %%
df[["col3"]]
# Out:
#    col3
# a     4
# b    86
# c    66
# d    73
# e    54

# %%
df.loc[["d","a","b"],["col3","col1"]]
# Out:
#    col3  col1
# d    73    54
# a     4    76
# b    86    96

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ozyur\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
len(sns.get_dataset_names())
# Out:
# 22

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df1 = df.copy() #orjinal dataseti kopyaladık.

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe().T #transpose(satır-sütun yer değiştirir) nümerik olanlar gelir
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
df.describe(include="object").T #sadece object değerleri verir
# Out:
#             count unique          top freq
# sex           891      2         male  577
# embarked      889      3            S  644
# who           891      3          man  537
# embark_town   889      3  Southampton  644
# alive         891      2           no  549

# %%
df.describe(include="all").T #tüm değerleri verir ama object olanlar nan döner
# Out:
#              count unique          top freq       mean        std   min  \
# survived     891.0    NaN          NaN  NaN   0.383838   0.486592   0.0
# pclass       891.0    NaN          NaN  NaN   2.308642   0.836071   1.0
# sex            891      2         male  577        NaN        NaN   NaN
# age          714.0    NaN          NaN  NaN  29.699118  14.526497  0.42
# sibsp        891.0    NaN          NaN  NaN   0.523008   1.102743   0.0
# parch        891.0    NaN          NaN  NaN   0.381594   0.806057   0.0
# fare         891.0    NaN          NaN  NaN  32.204208  49.693429   0.0
# embarked       889      3            S  644        NaN        NaN   NaN
# class          891      3        Third  491        NaN        NaN   NaN
# who            891      3          man  537        NaN        NaN   NaN
# adult_male     891      2         True  537        NaN        NaN   NaN
# deck           203      7            C   59        NaN        NaN   NaN
# embark_town    889      3  Southampton  644        NaN        NaN   NaN
# alive          891      2           no  549        NaN        NaN   NaN
# alone          891      2         True  537        NaN        NaN   NaN
#
#                 25%      50%   75%       max
# survived        0.0      0.0   1.0       1.0
# pclass          2.0      3.0   3.0       3.0
# sex             NaN      NaN   NaN       NaN
# age          20.125     28.0  38.0      80.0
# sibsp           0.0      0.0   1.0       8.0
# parch           0.0      0.0   0.0       6.0
# fare         7.9104  14.4542  31.0  512.3292
# embarked        NaN      NaN   NaN       NaN
# class           NaN      NaN   NaN       NaN
# who             NaN      NaN   NaN       NaN
# adult_male      NaN      NaN   NaN       NaN
# deck            NaN      NaN   NaN       NaN
# embark_town     NaN      NaN   NaN       NaN
# alive           NaN      NaN   NaN       NaN
# alone           NaN      NaN   NaN       NaN

# %%
df.survived.value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.survived.value_counts(normalize = True) #yüzde gibi bir değerlendirme yapar. 0 ile 1 arasında
# Out:
# survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.drop("survived", axis=1) #sütun silmek istediğimiz için axis=1 yaparız. default 0'dır.yoksa satırda arar bulamaz hata verir
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# 0         3    male  22.0      1      0   7.2500        S   Third    man
# 1         1  female  38.0      1      0  71.2833        C   First  woman
# 2         3  female  26.0      0      0   7.9250        S   Third  woman
# 3         1  female  35.0      1      0  53.1000        S   First  woman
# 4         3    male  35.0      0      0   8.0500        S   Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886       2    male  27.0      0      0  13.0000        S  Second    man
# 887       1  female  19.0      0      0  30.0000        S   First  woman
# 888       3  female   NaN      1      2  23.4500        S   Third  woman
# 889       1    male  26.0      0      0  30.0000        C   First    man
# 890       3    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# 2         False  NaN  Southampton   yes   True
# 3         False    C  Southampton   yes  False
# 4          True  NaN  Southampton    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN  Southampton    no   True
# 887       False    B  Southampton   yes   True
# 888       False  NaN  Southampton    no  False
# 889        True    C    Cherbourg   yes   True
# 890        True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
df.drop("survived", axis=1, inplace=True) #inplace=True kalıcı sileriz
df
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# 0         3    male  22.0      1      0   7.2500        S   Third    man
# 1         1  female  38.0      1      0  71.2833        C   First  woman
# 2         3  female  26.0      0      0   7.9250        S   Third  woman
# 3         1  female  35.0      1      0  53.1000        S   First  woman
# 4         3    male  35.0      0      0   8.0500        S   Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886       2    male  27.0      0      0  13.0000        S  Second    man
# 887       1  female  19.0      0      0  30.0000        S   First  woman
# 888       3  female   NaN      1      2  23.4500        S   Third  woman
# 889       1    male  26.0      0      0  30.0000        C   First    man
# 890       3    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# 2         False  NaN  Southampton   yes   True
# 3         False    C  Southampton   yes  False
# 4          True  NaN  Southampton    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN  Southampton    no   True
# 887       False    B  Southampton   yes   True
# 888       False  NaN  Southampton    no  False
# 889        True    C    Cherbourg   yes   True
# 890        True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
df.iloc[:100,:2]
# Out:
#     pclass     sex
# 0        3    male
# 1        1  female
# 2        3  female
# 3        1  female
# 4        3    male
# ..     ...     ...
# 95       3    male
# 96       1    male
# 97       1    male
# 98       2  female
# 99       2    male
#
# [100 rows x 2 columns]

# %% [markdown]
# ## <font color='blue'> <b>Conditional Selection</b><font color='black'>

# %%
df
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# 0         3    male  22.0      1      0   7.2500        S   Third    man
# 1         1  female  38.0      1      0  71.2833        C   First  woman
# 2         3  female  26.0      0      0   7.9250        S   Third  woman
# 3         1  female  35.0      1      0  53.1000        S   First  woman
# 4         3    male  35.0      0      0   8.0500        S   Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886       2    male  27.0      0      0  13.0000        S  Second    man
# 887       1  female  19.0      0      0  30.0000        S   First  woman
# 888       3  female   NaN      1      2  23.4500        S   Third  woman
# 889       1    male  26.0      0      0  30.0000        C   First    man
# 890       3    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# 2         False  NaN  Southampton   yes   True
# 3         False    C  Southampton   yes  False
# 4          True  NaN  Southampton    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN  Southampton    no   True
# 887       False    B  Southampton   yes   True
# 888       False  NaN  Southampton    no  False
# 889        True    C    Cherbourg   yes   True
# 890        True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
df > 50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 df > 50
#
# File c:\Users\ozyur\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\ozyur\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File c:\Users\ozyur\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:7631, in DataFrame._cmp_method(self, other, op)
#    7628 self, other = self._align_for_op(other, axis, flex=False, level=None)
#    7630 # See GH#4537 for discussion of scalar op behavior
# -> 7631 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7632 return self._construct_result(new_data)
#
# File c:\Users\ozyur\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:7676, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7673 right = lib.item_from_zerodim(right)
#    7674 if not is_list_like(right):
#    7675     # i.e. scalar, faster than checking np.ndim(right) == 0
# -> 7676     bm = self._mgr.apply(array_op, right=right)
#    7677     return self._constructor_from_mgr(bm, axes=bm.axes)
#    7679 elif isinstance(right, DataFrame):
#
# File c:\Users\ozyur\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     349             kwargs[k] = obj[b.mgr_locs.indexer]
#     351 if callable(f):
# --> 352     applied = b.apply(f, **kwargs)
#     353 else:
#     354     applied = getattr(b, f)(**kwargs)
#
# File c:\Users\ozyur\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File c:\Users\ozyur\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:346, in comparison_op(left, right, op)
#     343     return invalid_comparison(lvalues, rvalues, op)
#     345 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 346     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     348 else:
#     349     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\ozyur\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:131, in comp_method_OBJECT_ARRAY(op, x, y)
#     129     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     130 else:
# --> 131     result = libops.scalar_compare(x.ravel(), y, op)
#     132 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df[df>50]
# Out:
#    col1  col2  col3  col4
# a  76.0   NaN   NaN   NaN
# b  96.0  62.0  86.0   NaN
# c  69.0   NaN  66.0   NaN
# d  54.0  58.0  73.0  88.0
# e   NaN   NaN  54.0   NaN

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.age > 50
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
titanic [titanic.age > 50]["age"]
# Out:
# 6      54.0
# 11     58.0
# 15     55.0
# 33     66.0
# 54     65.0
#        ...
# 820    52.0
# 829    62.0
# 851    74.0
# 857    51.0
# 879    56.0
# Name: age, Length: 64, dtype: float64

# %%
 (titanic.age > 50) & (titanic.survived == 1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
titanic[(titanic.age > 50) & (titanic.survived == 1)]["sex"].value_counts()
# Out:
# sex
# female    16
# male       6
# Name: count, dtype: int64

# %% [markdown]
# ## <font color='blue'> <b>reset_index() & set_index()</b><font color='black'>

# %% [markdown]
# reset_index(), DataFrame indeksini sıfırlar ve bunun yerine default hali kullanır.
#
# set_index(), DataFrame'in belirtilen bir sütununu veya sütunlarını, DataFrame'in yeni bir indeksi olarak ayarlar.

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.set_index("pclass") # pclass'ı index yapar
# Out:
#         survived     sex   age  sibsp  parch     fare embarked   class    who  \
# pclass
# 3              0    male  22.0      1      0   7.2500        S   Third    man
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 3              1  female  26.0      0      0   7.9250        S   Third  woman
# 1              1  female  35.0      1      0  53.1000        S   First  woman
# 3              0    male  35.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 2              0    male  27.0      0      0  13.0000        S  Second    man
# 1              1  female  19.0      0      0  30.0000        S   First  woman
# 3              0  female   NaN      1      2  23.4500        S   Third  woman
# 1              1    male  26.0      0      0  30.0000        C   First    man
# 3              0    male  32.0      0      0   7.7500        Q   Third    man
#
#         adult_male deck  embark_town alive  alone
# pclass
# 3             True  NaN  Southampton    no  False
# 1            False    C    Cherbourg   yes  False
# 3            False  NaN  Southampton   yes   True
# 1            False    C  Southampton   yes  False
# 3             True  NaN  Southampton    no   True
# ...            ...  ...          ...   ...    ...
# 2             True  NaN  Southampton    no   True
# 1            False    B  Southampton   yes   True
# 3            False  NaN  Southampton    no  False
# 1             True    C    Cherbourg   yes   True
# 3             True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
titanic.set_index("pclass",drop=False) #pclass hem index olur hem de df 'de kalır
# Out:
#         survived  pclass     sex   age  sibsp  parch     fare embarked  \
# pclass
# 3              0       3    male  22.0      1      0   7.2500        S
# 1              1       1  female  38.0      1      0  71.2833        C
# 3              1       3  female  26.0      0      0   7.9250        S
# 1              1       1  female  35.0      1      0  53.1000        S
# 3              0       3    male  35.0      0      0   8.0500        S
# ...          ...     ...     ...   ...    ...    ...      ...      ...
# 2              0       2    male  27.0      0      0  13.0000        S
# 1              1       1  female  19.0      0      0  30.0000        S
# 3              0       3  female   NaN      1      2  23.4500        S
# 1              1       1    male  26.0      0      0  30.0000        C
# 3              0       3    male  32.0      0      0   7.7500        Q
#
#          class    who  adult_male deck  embark_town alive  alone
# pclass
# 3        Third    man        True  NaN  Southampton    no  False
# 1        First  woman       False    C    Cherbourg   yes  False
# 3        Third  woman       False  NaN  Southampton   yes   True
# 1        First  woman       False    C  Southampton   yes  False
# 3        Third    man        True  NaN  Southampton    no   True
# ...        ...    ...         ...  ...          ...   ...    ...
# 2       Second    man        True  NaN  Southampton    no   True
# 1        First  woman       False    B  Southampton   yes   True
# 3        Third  woman       False  NaN  Southampton    no  False
# 1        First    man        True    C    Cherbourg   yes   True
# 3        Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.reset_index() #index değerlerini sıfırladık
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 886    886         0       2    male  27.0      0      0  13.0000        S
# 887    887         1       1  female  19.0      0      0  30.0000        S
# 888    888         0       3  female   NaN      1      2  23.4500        S
# 889    889         1       1    male  26.0      0      0  30.0000        C
# 890    890         0       3    male  32.0      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 0     Third    man        True  NaN  Southampton    no  False
# 1     First  woman       False    C    Cherbourg   yes  False
# 2     Third  woman       False  NaN  Southampton   yes   True
# 3     First  woman       False    C  Southampton   yes  False
# 4     Third    man        True  NaN  Southampton    no   True
# ..      ...    ...         ...  ...          ...   ...    ...
# 886  Second    man        True  NaN  Southampton    no   True
# 887   First  woman       False    B  Southampton   yes   True
# 888   Third  woman       False  NaN  Southampton    no  False
# 889   First    man        True    C    Cherbourg   yes   True
# 890   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 16 columns]

# %%
titanic.reset_index(drop=True) #index değerlerini sıfırladık. drop yaparak df'den atarız
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
import seaborn as sns

# %%
titanic =sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.dropna() #tüm içinde nan olan satırları sildik. kalıcı değişiklik olmaz böyle
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [182 rows x 15 columns]

# %%
titanic.drop([3,100,150,142,825,888]) #kalıcı değil. bu satırları sildik
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# ..     ...         ...  ...          ...   ...    ...
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [885 rows x 15 columns]

# %%
titanic.drop([3,100,150,142,825,888], inplace=True) #kalıcı olur böyle. bu satırları sildik

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#tüm işlemler bitti. kalıcı olmayacak şekilde. silme, ayarlama. index değerleri de değişmiş oldu. sonra aşağıdaki işlemi yaparız

# %%
titanic.reset_index(drop=True) #drop=true index labeli bütün olarak kalmasını engeller
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.groupby("sex")["age"].mean() #cinsiyete göre yşa ortalaması
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
titanic.groupby("pclass")["fare"].mean() #sınıfa göre ücret ortalaması
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
titanic.groupby("sex")["age"].min() #cinsiyete göre en küçük yaşlar.
# Out:
# sex
# female    0.75
# male      0.42
# Name: age, dtype: float64

# %%
titanic.groupby("sex")["age"].max() #cinsiyete göre en büyük yaşlar.
# Out:
# sex
# female    63.0
# male      80.0
# Name: age, dtype: float64

# %%
import numpy as np

# %%
titanic.groupby("sex")["age"].agg([min,max,np.mean])
# Out:
# C:\Users\ozyur\AppData\Local\Temp\ipykernel_283048\632107600.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   titanic.groupby("sex")["age"].agg([min,max,np.mean])
# C:\Users\ozyur\AppData\Local\Temp\ipykernel_283048\632107600.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   titanic.groupby("sex")["age"].agg([min,max,np.mean])
# C:\Users\ozyur\AppData\Local\Temp\ipykernel_283048\632107600.py:1: FutureWarning: The provided callable <function mean at 0x00000208C15F7380> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   titanic.groupby("sex")["age"].agg([min,max,np.mean])
#          min   max       mean
# sex
# female  0.75  63.0  27.915709
# male    0.42  80.0  30.726645

# %%
titanic.groupby("sex")["survived"].count()
# Out:
# sex
# female    310
# male      575
# Name: survived, dtype: int64

# %%
titanic.groupby(["sex","survived"]).count()
# Out:
#                  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex    survived
# female 0             79   63     79     79    79        79     79   79
#        1            231  195    231    231   231       229    231  231
# male   0            466  359    466    466   466       466    466  466
#        1            109   93    109    109   109       109    109  109
#
#                  adult_male  deck  embark_town  alive  alone
# sex    survived
# female 0                 79     6           79     79     79
#        1                231    90          229    231    231
# male   0                466    61          466    466    466
#        1                109    45          109    109    109

# %%
titanic.groupby("sex")["survived"].count()
# Out:
# sex
# female    314
# male      577
# Name: survived, dtype: int64

# %%
titanic.groupby("sex")["survived"].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
titanic.groupby("sex")[["survived"]].mean()
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
titanic.groupby(["sex", "survived" ])["survived"].count()
# Out:
# sex     survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: survived, dtype: int64

# %%
titanic.groupby(["sex", "survived" ])[["survived"]].count()
# Out:
#                  survived
# sex    survived
# female 0               81
#        1              233
# male   0              468
#        1              109

# %%
pip install --upgrade pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pandas in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (2.1.3)
# Collecting pandas
#   Downloading pandas-2.2.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ozyur\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.1-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB 640.0 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.5 MB 1.2 MB/s eta 0:00:10
#     --------------------------------------- 0.2/11.5 MB 1.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/11.5 MB 1.9 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/11.5 MB 2.0 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/11.5 MB 2.0 MB/s eta 0:00:06
#    -- ------------------------------------- 0.7/11.5 MB 2.2 MB/s eta 0:00:05
#    -- ------------------------------------- 0.8/11.5 MB 2.2 MB/s eta 0:00:05
#    --- ------------------------------------ 0.9/11.5 MB 2.2 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/11.5 MB 2.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.2/11.5 MB 2.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.5 MB 2.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.4/11.5 MB 2.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.5/11.5 MB 2.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.5 MB 2.4 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.5 MB 2.4 MB/s eta 0:00:05
#    ------ --------------------------------- 1.9/11.5 MB 2.4 MB/s eta 0:00:05
#    ------ --------------------------------- 2.0/11.5 MB 2.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/11.5 MB 2.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.2/11.5 MB 2.4 MB/s eta 0:00:04
#    -------- ------------------------------- 2.3/11.5 MB 2.4 MB/s eta 0:00:04
#    -------- ------------------------------- 2.5/11.5 MB 2.4 MB/s eta 0:00:04
#    -------- ------------------------------- 2.6/11.5 MB 2.4 MB/s eta 0:00:04
#    --------- ------------------------------ 2.7/11.5 MB 2.4 MB/s eta 0:00:04
#    --------- ------------------------------ 2.8/11.5 MB 2.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.9/11.5 MB 2.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.1/11.5 MB 2.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.2/11.5 MB 2.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.3/11.5 MB 2.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.4/11.5 MB 2.5 MB/s eta 0:00:04
#    ------------ --------------------------- 3.5/11.5 MB 2.5 MB/s eta 0:00:04
#    ------------ --------------------------- 3.6/11.5 MB 2.5 MB/s eta 0:00:04
#    ------------- -------------------------- 3.7/11.5 MB 2.5 MB/s eta 0:00:04
#    ------------- -------------------------- 3.9/11.5 MB 2.5 MB/s eta 0:00:04
#    ------------- -------------------------- 4.0/11.5 MB 2.5 MB/s eta 0:00:04
#    -------------- ------------------------- 4.1/11.5 MB 2.5 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.5 MB 2.5 MB/s eta 0:00:03
#    -------------- ------------------------- 4.3/11.5 MB 2.5 MB/s eta 0:00:03
#    --------------- ------------------------ 4.4/11.5 MB 2.5 MB/s eta 0:00:03
#    --------------- ------------------------ 4.6/11.5 MB 2.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.5 MB 2.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.8/11.5 MB 2.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.9/11.5 MB 2.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.5 MB 2.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.1/11.5 MB 2.5 MB/s eta 0:00:03
#    ------------------ --------------------- 5.3/11.5 MB 2.5 MB/s eta 0:00:03
#    ------------------ --------------------- 5.4/11.5 MB 2.5 MB/s eta 0:00:03
#    ------------------- -------------------- 5.5/11.5 MB 2.5 MB/s eta 0:00:03
#    ------------------- -------------------- 5.6/11.5 MB 2.5 MB/s eta 0:00:03
#    ------------------- -------------------- 5.7/11.5 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.5 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 6.0/11.5 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 6.1/11.5 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 6.2/11.5 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 6.3/11.5 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.4/11.5 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.5/11.5 MB 2.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.6/11.5 MB 2.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.7/11.5 MB 2.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.9/11.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------ --------------- 7.0/11.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------- -------------- 7.2/11.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------- -------------- 7.4/11.5 MB 2.5 MB/s eta 0:00:02
#    -------------------------- ------------- 7.5/11.5 MB 2.5 MB/s eta 0:00:02
#    -------------------------- ------------- 7.6/11.5 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 7.8/11.5 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.5 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 8.0/11.5 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.1/11.5 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.2/11.5 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.3/11.5 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.4/11.5 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.6/11.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.8/11.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.9/11.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 9.0/11.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 9.1/11.5 MB 2.5 MB/s eta 0:00:01
#    -------------------------------- ------- 9.2/11.5 MB 2.5 MB/s eta 0:00:01
#    -------------------------------- ------- 9.3/11.5 MB 2.5 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.5 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 9.5/11.5 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.8/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.9/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.5 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.1/11.5 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.2/11.5 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.5 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.6/11.5 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.8/11.5 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 10.9/11.5 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.5 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 11.1/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.2/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 1.1 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.3
#     Uninstalling pandas-2.1.3:
#       Successfully uninstalled pandas-2.1.3
# Successfully installed pandas-2.2.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ozyur\AppData\Local\Programs\Python\Python312\Lib\site-packages\~andas.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ozyur\AppData\Local\Programs\Python\Python312\Lib\site-packages\~andas'.
#   You can safely remove it manually.

# %%
import pandas as pd

# %%
titanic.groupby(["sex","survived"])["survived"].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 titanic.groupby(["sex","survived"])["survived"].count()
#
# NameError: name 'titanic' is not defined

# %%
titanic.groupby(["sex","pclass","survived"])[["survived"]].count()
# Out:
#                         survived
# sex    pclass survived
# female 1      0                3
#               1               91
#        2      0                6
#               1               70
#        3      0               72
#               1               72
# male   1      0               77
#               1               45
#        2      0               91
#               1               17
#        3      0              300
#               1               47

# %%
titanic.groupby(["sex","pclass"])[["survived"]].value_counts(normalize=True)*100
# Out:
# sex     pclass  survived
# female  1       1           96.808511
#                 0            3.191489
#         2       1           92.105263
#                 0            7.894737
#         3       0           50.000000
#                 1           50.000000
# male    1       0           63.114754
#                 1           36.885246
#         2       0           84.259259
#                 1           15.740741
#         3       0           86.455331
#                 1           13.544669
# Name: proportion, dtype: float64

# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:100%;color:white;text-align:center;border-radius:20px 20px;"><b>Faydalı Olması Temennisiyle Teşekkürler</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |
